# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
racing_times_path = r"referenz_zeiten.csv"
race_times = pd.read_csv(racing_times_path)
race_times
# Out:
#                     Name   Highway99 Lap1   Highway99 Lap2   Highway99 Lap3  \
# 0  Nur Gas - ohne lenken              288              275              288
# 1                Model 1              179              189              198
# 2                Model 2              207              254              215
# 3                Maurice              220              191              197
# 4              Alexander              218              195              176
# 5                   Joël              148              157              150
# 6                Evelyne              296              257              257
# 7                Michael              231              202              202
# 8                 Kamila              293              271              266
#
#     Highway99 Lap4   Highway99 Lap5   Highway201 Lap1   Highway201 Lap2  \
# 0              280              288               211               215
# ...

# %%
race_times.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              9 non-null      object
#  1    Highway99 Lap1   9 non-null      int64
#  2    Highway99 Lap2   9 non-null      int64
#  3    Highway99 Lap3   9 non-null      int64
#  4    Highway99 Lap4   9 non-null      int64
#  5    Highway99 Lap5   9 non-null      int64
#  6    Highway201 Lap1  9 non-null      int64
#  7    Highway201 Lap2  9 non-null      int64
#  8    Highway201 Lap3  9 non-null      int64
#  9    Highway201 Lap4  9 non-null      int64
#  10   Highway201 Lap5  9 non-null      int64
# dtypes: int64(10), object(1)
# memory usage: 920.0+ bytes

# %%
high99 = race_times.iloc[:, 1:6]

# %%
plt.figure(figsize=(12, 8))
plt.grid("on")
plt.plot(high99.T)
plt.show()

# %%
print(high99.columns)
# Out:
# Index([' Highway99 Lap1', ' Highway99 Lap2', ' Highway99 Lap3',
#        ' Highway99 Lap4', ' Highway99 Lap5'],
#       dtype='object')
